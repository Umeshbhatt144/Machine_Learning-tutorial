# %% [markdown]
# <h1 align='center' style='color:purple'><b>Decision Trees - Part 1</b></h1>

# %% [markdown]
# A decision tree follows tree-like model of decisions and their possible outcomes. It is a way to represent an algorithm that only contains conditional control statements.
# It a flowchart-like structure. Each internal node represents a "test" on a feature whereas every branch represents the outcome of the test, & each terminal/leaf node represents the outcome which can be a continuous value or class label for regression and classification problem respectively.
#  - It is a Supervised Learning Algorithm.
#  - it can be used for both classification and regression problems.
#  - It can also handle non-linear data which was not possible in case of linear models
#
# Advantages :
#  - Simple and easy to understand and visualize
#  - Somewhat resistant to outliers
#  - No Feature Scaling is Required.
#
# Disadvantages :
#  - Overfitting
#  - High variance
#  - Not suitable for large Datasets

# %% [markdown]
# <b>Load the data that we will be using to train our model</b>
#
# Here we are using Titanic dataset which contains the data from one of the most infamous shipwrecks in history : The sinking of the Titanic.

# %% [markdown]
# <b> Import Necessary Libraries</b>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# <b>Get the data<b/>

# %%
import pandas as pd 
import io 

df = pd.read_csv("titanic.csv") 
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# <b>Data Dictionary</b>
#
# ##### Variable	& Definition
#  - Survived (Target) :	Survival of passenger	(0 = No, 1 = Yes)
#  - Pclass : Ticket class	(1 = 1st, 2 = 2nd, 3 = 3rd)
#  - Sex : Gender
#  - Age : Age in years
#  - Sibsp :	# of siblings / spouses aboard the Titanic
#  - Parch : # of parents / children aboard the Titanic
#  - Ticket :	Ticket number
#  - Fare :	Passenger fare
#  - Cabin : Cabin number
#  - Embarked :	Port of Embarkation	(C = Cherbourg, Q = Queenstown, S =  Southampton)

# %% [markdown]
# <b>Drop insignificant Variables<b/>

# %%
df.drop(['Name','SibSp','Parch','Ticket','Cabin','Embarked'],axis='columns',inplace=True)

# %% [markdown]
# As a person's survival may not depend on these variables.

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age     Fare
# 0            1         0       3    male  22.0   7.2500
# 1            2         1       1  female  38.0  71.2833
# 2            3         1       3  female  26.0   7.9250
# 3            4         1       1  female  35.0  53.1000
# 4            5         0       3    male  35.0   8.0500

# %% [markdown]
# <b>Separate Inputs and Target</b>

# %%
inputs = df.drop('Survived',axis='columns')
target = df.Survived

# %% [markdown]
# <b>Encode Categorical Variables 'Sex', as decision trees implemented in scikit-learn accepts numerical variables only.</b>

# %%
inputs.Sex = inputs.Sex.map({'male': 1, 'female': 2})

# %%
# print first 10 records
inputs.Age[:10]
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# 5     NaN
# 6    54.0
# 7     2.0
# 8    27.0
# 9    14.0
# Name: Age, dtype: float64

# %% [markdown]
# <b>We can see that there are a few NaN values in Age. So we will  fill those missing values with the avergae age.</b>

# %%
inputs.Age = inputs.Age.fillna(inputs.Age.mean())

# %%
# print first 10 records
inputs.Age[:10]
# Out:
# 0    22.000000
# 1    38.000000
# 2    26.000000
# 3    35.000000
# 4    35.000000
# 5    29.699118
# 6    54.000000
# 7     2.000000
# 8    27.000000
# 9    14.000000
# Name: Age, dtype: float64

# %% [markdown]
# The age of Passenger number 6 has been filled with the average age(29.699).

# %% [markdown]
# <b>Separate Training and Testing Data</b>

# %%
# import train_test_split from sklearn library
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(inputs,target,test_size=0.3)

# %% [markdown]
# Here test_size is used to specify test data size. 0.3 means 30% of data will be used for test data & remaining 70% will be used for training data.
#  X_train, y_train : inputs and target of training data
#  X_test, y_test : inputs and target of testing data

# %% [markdown]
# <b> Check the length of Traing and Testing Data</b>

# %%
print('Length of Training Data : {} that is 70% of original data.'.format(len(X_train)))
print('Length of Testing Data : {} that is 30% of original data.'.format(len(X_test)))
# Out:
# Length of Training Data : 623 that is 70% of original data.
# Length of Testing Data : 268 that is 30% of original data.

# %% [markdown]
# <b>Import Decision Tree Classifier</b>
# In this project, our target variable is of binary data type. So a Classification model will be used.

# %%
from sklearn import tree

# initialize a Decision Tree classifier model.
model = tree.DecisionTreeClassifier()

# %% [markdown]
# <b>Model Training</b> : Fitting/Training a model means that you're making your model learn the relationship b/w predictors and target so that you can predict the future values of the target.

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %% [markdown]
# <b>After model training, make predictions for thet testing data.</b>

# %%
model_accuracy = model.score(X_test,y_test)
print('Print model accuracy =',round(model_accuracy,3))
# Out:
# Print model accuracy = 0.761

# %% [markdown]
# model.score(X_test,ytest) : This function takes a feature matrix X_test and the expected target values y_test. Then y_testis compared with thet Predictions for X_test & either accuracy (for classification) or R2 score (for regression) is returned.

# %% [markdown]
# <b> Plot Decision Tree </b>

# %%
# Initialize a figure and use figsize to control the size of the rendered image.
plt.figure(figsize=(120,110))

# Plot Decision tree
tree.plot_tree(model, filled=True)

#Here filled is boolean parameter (default value = False) When set to True, 
#it paints the decisiontree nodes to indicate majority class for classification problem.
# Out:
# [Text(2971.201945754717, 5822.242105263158, 'X[2] <= 1.5\ngini = 0.461\nsamples = 623\nvalue = [399, 224]'),
#  Text(908.066037735849, 5507.526315789474, 'X[3] <= 13.0\ngini = 0.269\nsamples = 405\nvalue = [340, 65]'),
#  Text(126.33962264150944, 5192.8105263157895, 'X[1] <= 2.5\ngini = 0.469\nsamples = 24\nvalue = [9, 15]'),
#  Text(63.16981132075472, 4878.094736842106, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(189.50943396226415, 4878.094736842106, 'X[4] <= 17.344\ngini = 0.426\nsamples = 13\nvalue = [9, 4]'),
#  Text(126.33962264150944, 4563.378947368421, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(252.67924528301887, 4563.378947368421, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(1689.7924528301887, 5192.8105263157895, 'X[4] <= 26.4\ngini = 0.228\nsamples = 381\nvalue = [331, 50]'),
#  Text(734.3490566037736, 4878.094736842106, 'X[4] <= 7.91\ngini = 0.139\nsamples = 280\nvalue = [259, 21]'),
#  Text(379.0188679245283, 4563.378947368421, 'X[0] <= 44.5\ngini = 0.081\nsamples = 119\nvalue = [114, 5]'),
#  Text(252.67924528301887, 4248.663157894737, 'X[0] <= 33.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(189.50943396226415, 3933.9473684210525, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(315.8490566037736, 3933.9473684210525, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(505.35849056603774, 4248.663157894737, 'X[3] <= 27.5\ngini = 0.067\nsamples = 115\nvalue = [111, 4]'),
#  Text(442.188679245283, 3933.9473684210525, 'X[3] <= 26.5\ngini = 0.159\nsamples = 46\nvalue = [42, 4]'),
#  Text(379.0188679245283, 3619.2315789473687, 'X[4] <= 3.248\ngini = 0.124\nsamples = 45\nvalue = [42, 3]'),
#  Text(252.67924528301887, 3304.515789473684, 'X[3] <= 22.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(189.50943396226415, 2989.8, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(315.8490566037736, 2989.8, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(505.35849056603774, 3304.515789473684, 'X[3] <= 21.5\ngini = 0.089\nsamples = 43\nvalue = [41, 2]'),
#  Text(442.188679245283, 2989.8, 'X[3] <= 19.5\ngini = 0.188\nsamples = 19\nvalue = [17, 2]'),
#  Text(379.0188679245283, 2675.0842105263155, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(505.35849056603774, 2675.0842105263155, 'X[0] <= 693.5\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text
ngini = 0.117\nsamples = 16\nvalue = [1, 15]'),
#  Text(6064.301886792453, 2675.0842105263155, 'X[4] <= 20.167\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(6001.132075471698, 2360.3684210526317, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(6127.471698113208, 2360.3684210526317, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(6190.641509433963, 2675.0842105263155, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(6380.1509433962265, 2989.8, 'X[4] <= 17.379\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(6316.981132075472, 2675.0842105263155, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(6443.320754716981, 2675.0842105263155, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(6380.1509433962265, 3304.515789473684, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(6316.981132075472, 3933.9473684210525, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(6506.490566037736, 4878.094736842106, 'X[0] <= 49.0\ngini = 0.198\nsamples = 18\nvalue = [16, 2]'),
#  Text(6443.320754716981, 4563.378947368421, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(6569.66037735849, 4563.378947368421, 'X[3] <= 7.0\ngini = 0.111\nsamples = 17\nvalue = [16, 1]'),
#  Text(6506.490566037736, 4248.663157894737, 'X[4] <= 31.331\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(6443.320754716981, 3933.9473684210525, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(6569.66037735849, 3933.9473684210525, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(6632.830188679245, 4248.663157894737, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]')]

# %% [markdown]
# <b>Build a text report showing the rules of the Decision Tree model.</b>

# %%
print(tree.export_text(model))
# Out:
# |--- feature_2 <= 1.50
# |   |--- feature_3 <= 13.00
# |   |   |--- feature_1 <= 2.50
# |   |   |   |--- class: 1
# |   |   |--- feature_1 >  2.50
# |   |   |   |--- feature_4 <= 17.34
# |   |   |   |   |--- class: 1
# |   |   |   |--- feature_4 >  17.34
# |   |   |   |   |--- class: 0
# |   |--- feature_3 >  13.00
# |   |   |--- feature_4 <= 26.40
# |   |   |   |--- feature_4 <= 7.91
# |   |   |   |   |--- feature_0 <= 44.50
# |   |   |   |   |   |--- feature_0 <= 33.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_0 >  33.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_0 >  44.50
# |   |   |   |   |   |--- feature_3 <= 27.50
# |   |   |   |   |   |   |--- feature_3 <= 26.50
# |   |   |   |   |   |   |   |--- feature_4 <= 3.25
# |   |   |   |   |   |   |   |   |--- feature_3 <= 22.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_3 >  22.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_4 >  3.25
# |   |   |   |   |   |   |   |   |--- feature_3 <= 21.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 19.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  19.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 693.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  693.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_3 >  21.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_3 >  26.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_3 >  27.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- feature_4 >  7.91
# |   |   |   |   |--- feature_4 <= 7.99
# |   |   |   |   |   |--- feature_0 <= 397.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_0 >  397.00
# |   |   |   |   |   |   |--- feature_0 <= 472.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_0 >  472.00
# |   |   |   |   |   |   |   |--- feature_3 <= 31.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_3 >  31.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 554.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_0 >  554.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 608.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  608.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_4 >  7.99
# |   |   |   |   |   |--- feature_3 <= 60.50
# |   |   |   |   |   |   |--- feature_0 <= 19.50
# |   |   |   |   |   |   |   |--- feature_1 <= 2.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_1 >  2.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_0 >  19.50
# |   |   |   |   |   |   |   |--- feature_0 <= 220.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_0 >  220.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 221.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_0 >  221.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 341.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 336.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  336.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  341.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 32.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  32.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_3 >  60.50
# |   |   |   |   |   |   |--- feature_3 <= 63.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_3 >  63.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |--- feature_4 >  26.40
# |   |   |   |--- feature_0 <= 297.50
# |   |   |   |   |--- feature_3 <= 41.00
# |   |   |   |   |   |--- feature_3 <= 30.85
# |   |   |   |   |   |   |--- feature_0 <= 100.50
# |   |   |   |   |   |   |   |--- feature_0 <= 92.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_0 >  92.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_0 >  100.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_3 >  30.85
# |   |   |   |   |   |   |--- feature_4 <= 54.80
# |   |   |   |   |   |   |   |--- feature_3 <= 39.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_3 >  39.50
# |   |   |   |   |   |   |   |   |--- feature_4 <= 29.36
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_4 >  29.36
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_4 >  54.80
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_3 >  41.00
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- feature_0 >  297.50
# |   |   |   |   |--- feature_3 <= 57.00
# |   |   |   |   |   |--- feature_3 <= 47.50
# |   |   |   |   |   |   |--- feature_4 <= 30.60
# |   |   |   |   |   |   |   |--- feature_3 <= 39.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 29.85
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 762.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  762.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 811.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  811.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_3 >  29.85
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 32.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  32.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_3 >  39.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_4 >  30.60
# |   |   |   |   |   |   |   |--- feature_4 <= 52.28
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_4 >  52.28
# |   |   |   |   |   |   |   |   |--- feature_4 <= 63.28
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 737.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  737.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 30.85
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  30.85
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_4 >  63.28
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 17.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  17.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 388.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  388.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |--- feature_3 >  47.50
# |   |   |   |   |   |   |--- feature_0 <= 546.50
# |   |   |   |   |   |   |   |--- feature_0 <= 461.00
# |   |   |   |   |   |   |   |   |--- feature_0 <= 442.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_0 >  442.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_0 >  461.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_0 >  546.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_3 >  57.00
# |   |   |   |   |   |--- feature_3 <= 75.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_3 >  75.50
# |   |   |   |   |   |   |--- class: 1
# |--- feature_2 >  1.50
# |   |--- feature_1 <= 2.50
# |   |   |--- feature_4 <= 28.86
# |   |   |   |--- feature_4 <= 28.23
# |   |   |   |   |--- feature_0 <= 48.00
# |   |   |   |   |   |--- feature_0 <= 29.00
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_0 >  29.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_0 >  48.00
# |   |   |   |   |   |--- feature_0 <= 828.50
# |   |   |   |   |   |   |--- feature_3 <= 26.50
# |   |   |   |   |   |   |   |--- feature_3 <= 25.00
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_3 >  25.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_3 >  26.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_0 >  828.50
# |   |   |   |   |   |   |--- feature_0 <= 859.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_0 >  859.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- feature_4 >  28.23
# |   |   |   |   |--- class: 0
# |   |   |--- feature_4 >  28.86
# |   |   |   |--- feature_4 <= 143.03
# |   |   |   |   |--- class: 1
# |   |   |   |--- feature_4 >  143.03
# |   |   |   |   |--- feature_4 <= 152.51
# |   |   |   |   |   |--- feature_3 <= 23.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_3 >  23.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_4 >  152.51
# |   |   |   |   |   |--- class: 1
# |   |--- feature_1 >  2.50
# |   |   |--- feature_4 <= 24.81
# |   |   |   |--- feature_4 <= 7.74
# |   |   |   |   |--- feature_0 <= 302.00
# |   |   |   |   |   |--- feature_4 <= 7.64
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_4 >  7.64
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_0 >  302.00
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- feature_4 >  7.74
# |   |   |   |   |--- feature_4 <= 15.37
# |   |   |   |   |   |--- feature_0 <= 92.00
# |   |   |   |   |   |   |--- feature_3 <= 14.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_3 >  14.50
# |   |   |   |   |   |   |   |--- feature_3 <= 35.00
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_3 >  35.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_0 >  92.00
# |   |   |   |   |   |   |--- feature_0 <= 157.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_0 >  157.00
# |   |   |   |   |   |   |   |--- feature_0 <= 229.00
# |   |   |   |   |   |   |   |   |--- feature_4 <= 9.19
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_4 >  9.19
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_0 >  229.00
# |   |   |   |   |   |   |   |   |--- feature_3 <= 7.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_3 >  7.00
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 28.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 528.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  528.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  28.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 254.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  254.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |--- feature_4 >  15.37
# |   |   |   |   |   |--- feature_0 <= 874.00
# |   |   |   |   |   |   |--- feature_0 <= 55.50
# |   |   |   |   |   |   |   |--- feature_4 <= 17.35
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_4 >  17.35
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_0 >  55.50
# |   |   |   |   |   |   |   |--- feature_3 <= 38.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 651.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 20.17
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  20.17
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_0 >  651.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 17.38
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  17.38
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_3 >  38.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_0 >  874.00
# |   |   |   |   |   |   |--- class: 0
# |   |   |--- feature_4 >  24.81
# |   |   |   |--- feature_0 <= 49.00
# |   |   |   |   |--- class: 1
# |   |   |   |--- feature_0 >  49.00
# |   |   |   |   |--- feature_3 <= 7.00
# |   |   |   |   |   |--- feature_4 <= 31.33
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_4 >  31.33
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_3 >  7.00
# |   |   |   |   |   |--- class: 0

# %% [markdown]
# [<b> Minimal Cost-Complexity Pruning</b>](https://scikit-learn.org/stable/auto_examples/tree/plot_cost_complexity_pruning.html)
# Minimal cost-complexity pruning is an algorithm used to prune a tree to avoid over-fitting. This pruning technique is parameterized by the cost complexity parameter, ccp_alpha. Greater values of ccp_alpha increase the number of nodes pruned.
# ccp_alpha : (non-negative float, default=0.0)
# Complexity parameter used for Minimal Cost-Complexity Pruning. The subtree with the largest cost complexity that is smaller than ccp_alpha will be chosen. By default, no pruning is performed.

# %%
path = model.cost_complexity_pruning_path(X_train, y_train)
ccp_alphas, impurities = path.ccp_alphas, path.impurities

# %%
ccp_alphas
# Out:
# array([0.        , 0.00105412, 0.00107009, 0.00107009, 0.00122438,
#        0.00125443, 0.00128411, 0.00128411, 0.00135819, 0.00137583,
#        0.00142679, 0.00142679, 0.00143342, 0.00144462, 0.00149813,
#        0.00151072, 0.001595  , 0.00159704, 0.00160514, 0.00162987,
#        0.00171215, 0.00192616, 0.00208311, 0.00213243, 0.0021343 ,
#        0.00214018, 0.00228956, 0.00241348, 0.00249688, 0.00264978,
#        0.00268572, 0.00285358, 0.00288925, 0.00288925, 0.00342429,
#        0.00402673, 0.0040649 , 0.00409527, 0.00650891, 0.00888999,
#        0.0091678 , 0.0097865 , 0.01072248, 0.01767121, 0.03860282,
#        0.14722524])

# %% [markdown]
# DecisionTreeClassifier.cost_complexity_pruning_path : returns the effective alphas and the corresponding total leaf impurities at each step of the pruning process. As alpha increases, more of the tree is pruned, which increases the total impurity of its leaves.

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# <b>For each value of ccp_alpha, train a DecisionTree model and store it in models.</b>

# %%
models = []
for ccp_alpha in ccp_alphas:
    model = DecisionTreeClassifier(random_state=0, ccp_alpha=ccp_alpha)
    model.fit(X_train, y_train)
    models.append(model)
print("Number of nodes in the last tree is: {} with ccp_alpha: {}".format(
      models[-1].tree_.node_count, ccp_alphas[-1]))
# Out:
# Number of nodes in the last tree is: 1 with ccp_alpha: 0.1472252418330412

# %% [markdown]
# <b>For all the models trained for different values of ccp_alpha, find training and testing accuracy and plot it.</b>

# %%
# Calculate train and test accuracy of all the models
train_scores = [model.score(X_train, y_train) for model in models]
test_scores = [model.score(X_test, y_test) for model in models]

# plot training and testingaccuracy
fig, ax = plt.subplots(figsize = (18,6))
ax.set_xlabel("alpha", fontsize = 14)
ax.set_ylabel("Accuracy", fontsize = 14)
ax.set_title("Accuracy vs alpha for training and testing sets", fontsize = 16)
ax.plot(ccp_alphas, train_scores, marker='o', label="train",
        drawstyle="steps-post")
ax.plot(ccp_alphas, test_scores, marker='o', label="test",
        drawstyle="steps-post")
ax.legend()
plt.show()

# %% [markdown]
#  - From the above plot, it is clear that around 0.003 ccp_alpha, model accuracy for test data is highest.
#  - It can also be noted that near 0.003 ccp_alpha, training and testing accuracies are almost equal which means model is not over-fitting.

# %% [markdown]
# <b> Train Final Decision tree model with the selected value of ccp_alpha.</b>

# %%
model = DecisionTreeClassifier(random_state=0, ccp_alpha=0.003)
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.003, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=0, splitter='best')

# %%
# Make predictions for testing data
pred=model.predict(X_test)

# Import accuracy_score, which also calculates the accuracy of predictions
from sklearn.metrics import accuracy_score
print('Model accuracy after post-pruning :',round(accuracy_score(y_test, pred),3))
# Out:
# Model accuracy after post-pruning : 0.769

# %% [markdown]
# The model accuracy after post pruning increased. This shows that without post pruning, our initial decisionTree model was over-fitting on the training data.

# %% [markdown]
# <b> Lets visualize our final DecisonTree model to observe the effect of post-pruning. </b>

# %%
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(model,filled=True)
# Out:
# [Text(448.3928571428571, 516.4200000000001, 'X[2] <= 1.5\ngini = 0.461\nsamples = 623\nvalue = [399, 224]'),
#  Text(239.14285714285714, 462.06000000000006, 'X[3] <= 13.0\ngini = 0.269\nsamples = 405\nvalue = [340, 65]'),
#  Text(119.57142857142857, 407.70000000000005, 'X[1] <= 2.5\ngini = 0.469\nsamples = 24\nvalue = [9, 15]'),
#  Text(59.785714285714285, 353.34000000000003, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(179.35714285714286, 353.34000000000003, 'X[4] <= 17.344\ngini = 0.426\nsamples = 13\nvalue = [9, 4]'),
#  Text(119.57142857142857, 298.98, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(239.14285714285714, 298.98, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(358.7142857142857, 407.70000000000005, 'X[4] <= 26.4\ngini = 0.228\nsamples = 381\nvalue = [331, 50]'),
#  Text(298.92857142857144, 353.34000000000003, 'gini = 0.139\nsamples = 280\nvalue = [259, 21]'),
#  Text(418.5, 353.34000000000003, 'X[0] <= 297.5\ngini = 0.409\nsamples = 101\nvalue = [72, 29]'),
#  Text(358.7142857142857, 298.98, 'gini = 0.161\nsamples = 34\nvalue = [31, 3]'),
#  Text(478.2857142857143, 298.98, 'X[3] <= 57.0\ngini = 0.475\nsamples = 67\nvalue = [41, 26]'),
#  Text(418.5, 244.62, 'X[3] <= 47.5\ngini = 0.492\nsamples = 57\nvalue = [32, 25]'),
#  Text(358.7142857142857, 190.26000000000005, 'X[4] <= 30.598\ngini = 0.473\nsamples = 47\nvalue = [29, 18]'),
#  Text(239.14285714285714, 135.90000000000003, 'X[3] <= 39.5\ngini = 0.444\nsamples = 12\nvalue = [4, 8]'),
#  Text(179.35714285714286, 81.54000000000002, 'gini = 0.32\nsamples = 10\nvalue = [2, 8]'),
#  Text(298.92857142857144, 81.54000000000002, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(478.2857142857143, 135.90000000000003, 'X[4] <= 52.277\ngini = 0.408\nsamples = 35\nvalue = [25, 10]'),
#  Text(418.5, 81.54000000000002, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(538.0714285714286, 81.54000000000002, 'X[4] <= 63.275\ngini = 0.491\nsamples = 23\nvalue = [13, 10]'),
#  Text(478.2857142857143, 27.180000000000064, 'gini = 0.346\nsamples = 9\nvalue = [2, 7]'),
#  Text(597.8571428571429, 27.180000000000064, 'gini = 0.337\nsamples = 14\nvalue = [11, 3]'),
#  Text(478.2857142857143, 190.26000000000005, 'gini = 0.42\nsamples = 10\nvalue = [3, 7]'),
#  Text(538.0714285714286, 244.62, 'gini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(657.6428571428571, 462.06000000000006, 'X[1] <= 2.5\ngini = 0.395\nsamples = 218\nvalue = [59, 159]'),
#  Text(597.8571428571429, 407.70000000000005, 'gini = 0.085\nsamples = 113\nvalue = [5, 108]'),
#  Text(717.4285714285714, 407.70000000000005, 'X[4] <= 24.808\ngini = 0.5\nsamples = 105\nvalue = [54, 51]'),
#  Text(657.6428571428571, 353.34000000000003, 'X[4] <= 7.744\ngini = 0.492\nsamples = 87\nvalue = [38, 49]'),
#  Text(597.8571428571429, 298.98, 'gini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(717.4285714285714, 298.98, 'X[4] <= 15.373\ngini = 0.499\nsamples = 78\nvalue = [37, 41]'),
#  Text(657.6428571428571, 244.62, 'X[0] <= 92.0\ngini = 0.492\nsamples = 55\nvalue = [31, 24]'),
#  Text(597.8571428571429, 190.26000000000005, 'gini = 0.346\nsamples = 9\nvalue = [2, 7]'),
#  Text(717.4285714285714, 190.26000000000005, 'gini = 0.466\nsamples = 46\nvalue = [29, 17]'),
#  Text(777.2142857142857, 244.62, 'gini = 0.386\nsamples = 23\nvalue = [6, 17]'),
#  Text(777.2142857142857, 353.34000000000003, 'gini = 0.198\nsamples = 18\nvalue = [16, 2]')]

# %% [markdown]
# <b>It can be observed that after post-pruning, the size of decision tree reduced.</b>
